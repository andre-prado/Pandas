# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
## Read Headers
#df.columns # mostra o nome de todas as colunas

### Read each Column
#print(df['Name'])
#df['Name'][0:5]
#df[['Name', 'HP', 'Attack']]

### Read each Row
#df.iloc[0:3]
#for index, row in df.iterrows():
    #print(index, row['Type 1'], row['Name'])
df.loc[df['Type 1'] == "Fire"]
    
    
### Read a specific Location (R,C )
#df.iloc[0, 4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-f355a0e6549f> in <module>
#      11 #for index, row in df.iterrows():
#      12     #print(index, row['Type 1'], row['Name'])
# ---> 13 df.loc[df['Type 1'] == "Fire" and df['Type 2'] == "Grass"]
#      14
#      15
#
# c:\users\andr3\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
  df.sort_values("Name", ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]
